# %% [markdown]
# # Diabetes Data Set
#
# Dataset file: 'diabetes.data'
# Reference link for description of dataset: https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html

# %% [markdown]
# ### Preview of the Data Set
#
# Load the data set.
#
# a) Analyse the data set. Print the number of features, feature names, data types of the features, number of data points and the values of the first 10 data points.

# %%
import pandas as pd
import numpy as np

# %%
#df1=pd.read_data("diabetes.data")
df1=pd.read_csv("C:/Users/vishn/OneDrive/Desktop/Data Analytics Lab/Week 3/diabetes.data", sep="	")

# %%
df1.head(n = 10)
#diabetes = datasets.load_diabetes()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3    S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.00  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.00  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.00  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.00  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.00  4.2905  80  135
# 5   23    1  22.6   89.0  139   64.8  61.0  2.00  4.1897  68   97
# 6   36    2  22.0   90.0  160   99.6  50.0  3.00  3.9512  82  138
# 7   66    2  26.2  114.0  255  185.0  56.0  4.55  4.2485  92   63
# 8   60    2  32.1   83.0  179  119.4  42.0  4.00  4.4773  94  110
# 9   29    1  30.0   85.0  180   93.4  43.0  4.00  5.3845  88  310

# %%
df1.shape
# Out:
# (442, 11)

# %%
df1.dtypes
# Out:
# AGE      int64
# SEX      int64
# BMI    float64
# BP     float64
# S1       int64
# S2     float64
# S3     float64
# S4     float64
# S5     float64
# S6       int64
# Y        int64
# dtype: object

# %%
for col in df1.columns: 
    print(col)
# Out:
# AGE
# SEX
# BMI
# BP
# S1
# S2
# S3
# S4
# S5
# S6
# Y

# %%
df = df1.drop(['Y'], axis =1)

# %%
df
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80
# 5     23    1  22.6   89.00  139   64.8  61.0  2.00  4.1897   68
# 6     36    2  22.0   90.00  160   99.6  50.0  3.00  3.9512   82
# 7     66    2  26.2  114.00  255  185.0  56.0  4.55  4.2485   92
# 8     60    2  32.1   83.00  179  119.4  42.0  4.00  4.4773   94
# 9     29    1  30.0   85.00  180   93.4  43.0  4.00  5.3845   88
# 10    22    1  18.6   97.00  114   57.6  46.0  2.00  3.9512   83
# 11    56    2  28.0   85.00  184  144.8  32.0  6.00  3.5835   77
# 12    53    1  23.7   92.00  186  109.2  62.0  3.00  4.3041   81
# ...

# %% [markdown]
# ### Training and Testing Data Sets
#
# b) Split the data set into training and testing data set with a 80:20 ratio.
#
# (Hint: What precautions must you take before you split the data set?)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, df1.Y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Linear Regression
#
# c) Using linear regression, seek a model for the response of interest ($Y$), as a function of the baseline variables such as age, sex, body mass index, etc. Compute the training error and testing error.

# %%
from sklearn.metrics import mean_squared_error
model = LinearRegression()
model.fit(X_train, y_train)
y_train_predicted = model.predict(X_train)
y_test_predicted = model.predict(X_test)
rmse_train = mean_squared_error(y_train, y_train_predicted)
rmse_test = mean_squared_error(y_test, y_test_predicted)
print("Train Error: ",rmse_train,"\n","Test Error: ",rmse_test)
# Out:
# Train Error:  2734.7508990757424
#  Test Error:  3424.259334298694

# %% [markdown]
# ### Data Preprocessing
#
# d) Normalize the data set and perform linear regression again. Compute the training error and testing error. Comment.

# %%
from sklearn import preprocessing

# %%
df3 = sklearn.preprocessing.normalize(df1)

# %%
df3 = pd.DataFrame(df3)

# %%
df4 = df3.drop(df3.columns[10], axis =1)

# %%
X_train, X_test, y_train, y_test = train_test_split(df4, df3[10], test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_train_predicted = model.predict(X_train)
y_test_predicted = model.predict(X_test)
rmse_train = mean_squared_error(y_train, y_train_predicted)
rmse_test = mean_squared_error(y_test, y_test_predicted)
print("Train Error: ",rmse_train,"\n","Test Error: ",rmse_test)
# Out:
# Train Error:  0.0015615770552449009
#  Test Error:  0.0016164253245794654

# %%
model.coef_
# Out:
# array([-0.35540996, -1.21011049, -0.56017467, -0.64224831, -1.25032664,
#        -0.54237399, -0.63607066, -3.66731231,  8.00368537, -0.63798254])

# %% [markdown]
# ### Feature Reduction
#
# e) Rank the features in order of importance (based on the study in d)). Comment.

# %% [markdown]
# S5,S4, S1, SEX, BP,S6, S3,BMI,S2, AGE. The higher the absolute value of coefficients the more important the parameter is.

# %% [markdown]
# ### Polynomial Regression
#
# f) Repeat the exercise in d) with quadratic features. List the features you would add to the existing data set. Compute the training error and the testing error. Comment.

# %%
df5 = df3.drop(df3.columns[[10,7,3,6,1]], axis =1)

# %%
X_train, X_test, y_train, y_test = train_test_split(df5, df3[10], test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
polynomial_features = PolynomialFeatures(degree=2)
X_poly = polynomial_features.fit_transform(X_train)
model = LinearRegression()
model.fit(X_poly, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=2)
x_train_poly = polynomial_features.fit_transform(X_train)
model = LinearRegression()
model.fit(x_train_poly, y_train)
y_train_poly_pred = model.predict(x_train_poly)
x_test_poly = polynomial_features.fit_transform(X_test)
y_test_poly_pred = model.predict(x_test_poly)
mse_train = (mean_squared_error(y_train,y_train_poly_pred))
error_train = (mse_train)
mse_test = (mean_squared_error(y_test,y_test_poly_pred))
error_test = (mse_test)
print("Train Error : ",error_train,"\n","Test Error : ",error_test)
# Out:
# Train Error :  0.001341577535735313
#  Test Error :  0.0017168762006729112

# %% [markdown]
# Polynomial Regression is much better as it has beter score.
